# %% [markdown]
# # Best Neighborhood
# ## By Dastan Abdulla, Anna Speciale, and Lucas Milavec

# %% [markdown]
# ### Public Safety (Dastan Abdulla)

# %%
#imports
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#reading data
ps = pd.read_csv("./data/public-safety.csv")
ps
# Out:
#            Neighborhood  Sector # Population (2010)  \
# 0      Allegheny Center         3               933
# 1        Allegheny West         3               462
# 2             Allentown         6             2,500
# 3             Arlington         7             1,869
# 4     Arlington Heights         7               244
# ..                  ...       ...               ...
# 85  Upper Lawrenceville        13             2,669
# 86             West End         4               254
# 87         West Oakland        14             2,604
# 88             Westwood         4             3,066
# 89              Windgap         4             1,369
#
#     #Part 1 (Major Crime) Reports (2010)  #Part 2 Reports (2010)  \
# 0                                     71                     141
# 1                                     38                      49
# 2                                    159                     252
# 3                                     50                      84
# ...

# %%
#removing unneccessary columns
ps = ps.drop(columns=["Sector #", "Part 1 Crime per 100 Persons (2010)", "Part 2 Crime per 100 Persons (2010)"])
ps
# Out:
#            Neighborhood Population (2010)  \
# 0      Allegheny Center               933
# 1        Allegheny West               462
# 2             Allentown             2,500
# 3             Arlington             1,869
# 4     Arlington Heights               244
# ..                  ...               ...
# 85  Upper Lawrenceville             2,669
# 86             West End               254
# 87         West Oakland             2,604
# 88             Westwood             3,066
# 89              Windgap             1,369
#
#     #Part 1 (Major Crime) Reports (2010)  #Part 2 Reports (2010)  \
# 0                                     71                     141
# 1                                     38                      49
# 2                                    159                     252
# 3                                     50                      84
# 4                                     19                      37
# ...

# %%
#relabeling 
names = {"Neighborhood":"Neighborhood", "Population (2010)":"Population", "#Part 1 (Major Crime) Reports (2010)":"Major Crime Reports", "#Part 2 Reports (2010)":"Reports", "#Other Police Reports (2010)":"Other Reports", "#Murder (2010)":"Murder", "#Rape (2010)": "Rape", "#Robbery (2010)":"Robbery", "#Agr. Assault (2010)":"Aggrevated Assault", "#Burglary (2010)":"Burglary", "#Auto Theft (2010)":"Auto Theft", "#Drug Violations (2010)":"Drug Violations"}
ps.rename(columns=names, inplace=True)
ps
# Out:
#            Neighborhood Population  Major Crime Reports  Reports  \
# 0      Allegheny Center        933                   71      141
# 1        Allegheny West        462                   38       49
# 2             Allentown      2,500                  159      252
# 3             Arlington      1,869                   50       84
# 4     Arlington Heights        244                   19       37
# ..                  ...        ...                  ...      ...
# 85  Upper Lawrenceville      2,669                   92      184
# 86             West End        254                   23       54
# 87         West Oakland      2,604                   82       65
# 88             Westwood      3,066                   57       53
# 89              Windgap      1,369                   41       40
#
#     Other Reports  Murder  Rape  Robbery  Aggrevated Assault  Burglary  \
# 0              46       0     2        9                   5         8
# ...

# %%
#population plot and reporting rates
population = ps["Population"].str.replace(",", "").astype(float)
neighborhood = ps["Neighborhood"]
major_reps = ps["Major Crime Reports"]
reps = ps["Reports"]
plt.figure(figsize = (30,20))
plt.xticks(rotation = 90)
plt.bar(neighborhood, population, color = "C0", label = "population")
plt.bar(neighborhood, major_reps, color = "C1", label = "major crime reports")
plt.bar(neighborhood, reps, color = "C2", label = "crime reports")
plt.legend()

# %%
murder = ps["Murder"]
rape = ps["Rape"]
robbery	= ps["Robbery"]
aggrevated_Assault = ps["Aggrevated Assault"]	
burglary = ps["Burglary"]	
auto_Theft = ps["Auto Theft"]
drug_Violations = ps["Drug Violations"]
plt.figure(figsize = (30,20))
plt.xticks(rotation = 90)
plt.bar(neighborhood, murder, color="C6", label = "murder")
plt.bar(neighborhood, rape, color="C5", bottom=murder, label = "rape")
plt.bar(neighborhood, robbery, color="C4", bottom=rape, label = "robbery")
plt.bar(neighborhood, aggrevated_Assault, color="C3", bottom=robbery, label = "aggrevated assault")
plt.bar(neighborhood, burglary, color="C2", bottom=aggrevated_Assault, label = "burglary")
plt.bar(neighborhood, auto_Theft, color="C1", bottom=burglary, label = "auto theft")
plt.bar(neighborhood, drug_Violations, color="C0", bottom=auto_Theft, label = "drug violations")
plt.legend()

# %%
# Out:
#            Neighborhood Population  Major Crime Reports  Reports  \
# 0      Allegheny Center        933                   71      141
# 1        Allegheny West        462                   38       49
# 2             Allentown      2,500                  159      252
# 3             Arlington      1,869                   50       84
# 4     Arlington Heights        244                   19       37
# ..                  ...        ...                  ...      ...
# 85  Upper Lawrenceville      2,669                   92      184
# 86             West End        254                   23       54
# 87         West Oakland      2,604                   82       65
# 88             Westwood      3,066                   57       53
# 89              Windgap      1,369                   41       40
#
#     Other Reports  Murder  Rape  Robbery  Aggrevated Assault  Burglary  \
# 0              46       0     2        9                   5         8
# ...

# %%
#neghborgood class
class Neighborhood:
    def __init__(self, name, population, mu, ra, ro, ag, bu, au, dr):
        self.name = name
        self.population = population
        self.murder = mu
        self.rape = ra
        self.robbery = ro
        self.assault = ag
        self.burglary = bu
        self.auto = au
        self.drug = dr
        self.score = (self.murder + self.rape + self.robbery + self.assault + self.burglary + self.auto + self.drug)/int(self.population)
    def getScore(self):
        return self.score
    def getName(self):
        return self.name
    def getStats(self):
        info = self.name + ", " + str(self.population)
        return info

# %%
#making element class list
neighborhoods_list = []
for index, nh in ps.iterrows():
    nh_name = nh["Neighborhood"]
    nh_population = nh["Population"].replace(",", "")
    nh_murder = nh["Murder"]
    nh_rape = nh["Rape"]
    nh_robbery = nh["Robbery"]
    nh_assault = nh["Aggrevated Assault"]
    nh_burglary = nh["Burglary"]
    nh_auto = nh["Auto Theft"]
    nh_drug = nh["Drug Violations"]
    neighborhoods_elmnt = Neighborhood(nh_name, nh_population, nh_murder, nh_rape, nh_robbery, nh_assault, nh_burglary, nh_auto, nh_drug)
    neighborhoods_list.append(neighborhoods_elmnt)

# %%
from operator import itemgetter
names_and_scores = []
for nh in neighborhoods_list:
    name_score = []
    name_score.append(nh.getName())
    name_score.append(nh.getScore() * 100)
    names_and_scores.append(name_score)
sorted_names_and_scores = sorted(names_and_scores, key=itemgetter(1), reverse=False)
print(sorted_names_and_scores)
# Out:
# [['Fairywood', 0.09980039920159679], ['New Homestead', 0.40404040404040403], ['Swisshelm Park', 0.440852314474651], ['Lincoln Place', 0.5268050821196157], ['Summer Hill', 0.570884871550904], ['Squirrel Hill North', 0.6248349907594825], ['Banksville', 0.6756756756756757], ['Oakwood', 0.7789678675754625], ['North Oakland', 0.7866552933371244], ['Squirrel Hill South', 0.886829913964262], ['Stanton Heights', 1.0215170615083677], ['Point Breeze', 1.03480714957667], ['Westwood', 1.0437051532941943], ['East Carnegie', 1.0526315789473684], ['Brookline', 1.0821855607688815], ['Shadyside', 1.164211282788358], ['Regent Square', 1.1853448275862069], ['Ridgemont', 1.2422360248447204], ['Greenfield', 1.3161502604880724], ['Duquesne Heights', 1.3195876288659794], ['Bluff', 1.3333333333333335], ['Glen Hazel', 1.536312849162011], ['Morningside', 1.5540944411237299], ['Beechview', 1.6428392274893404], ['Overbrook', 1.646542261251372], ['Highland Park', 1.7670054730258016], ['Upper Hill', 1.89596499756
# ...

# %%
plt.figure(figsize = (30,20))
plt.xticks(rotation = 90)
plt.bar([name[0] for name in sorted_names_and_scores], [score[1] for score in sorted_names_and_scores] , color="C0", label = "scores")
# Out:
# <BarContainer object of 90 artists>

# %% [markdown]
# ## Dastan Abdulla's Conclusion
# After a thorough analysis of the given data, we can conclude that the safest neighborhood is Fairywood. However, the rest of the neighborhoods are incredibly close, except for West End, South Shore, and Chateau. The methodology used in the analysis considers various factors such as murder, rape, robbery, drug use, assaults, and auto theft. I divided the total of the crimes by the neighborhood population to calculate a relative percentage of overall crime.

# %% [markdown]
# ### Land Zoning (Lucas Milavec)

# %%
import pandas as pd
import matplotlib.pyplot as plt
zone = pd.read_csv("./data/land-use-zoning.csv", sep=",")
zone.head(10)
# Out:
#         Neighborhood  Sector # Population (2010) Land Area (acres)  \
# 0   Allegheny Center         3               933             134.4
# 1     Allegheny West         3               462              90.2
# 2          Allentown         6             2,500             188.8
# 3          Arlington         7             1,869             300.8
# 4  Arlington Heights         7               244              84.5
# 5         Banksville         5             4,144             620.2
# 6  Bedford Dwellings        15             1,202             114.6
# 7          Beechview         5             7,974             934.4
# 8        Beltzhoover         6             1,925             269.4
# 9         Bloomfield        12             8,442             449.3
#
#   Residential Mixed Use / Commercial Mixed Use / Industrial  \
# 0        0.0%                  49.4%                   0.0%
# 1       42.1%                  12.5%                   6.3%
# ...

# %% [markdown]
# I start by opening the file and viewing the first 10 rows to check everything is working.

# %%
zoning_score = dict()

for index,row in zone.iterrows():
    name = row[0]
    average = 0.0
    for i in range(4,8):
        average += float(row[i][:-1])
    average = average/4
    zoning_score[name] = average
    
zoning_score
# Out:
# {'Allegheny Center': 12.35,
#  'Allegheny West': 21.825,
#  'Allentown': 15.975000000000001,
#  'Arlington': 14.6,
#  'Arlington Heights': 14.125,
#  'Banksville': 21.175,
#  'Bedford Dwellings': 15.55,
#  'Beechview': 15.524999999999999,
#  'Beltzhoover': 17.175,
#  'Bloomfield': 23.6,
#  'Bluff': 18.975,
#  'Bon Air': 12.774999999999999,
#  'Brighton Heights': 16.95,
#  'Brookline': 19.549999999999997,
#  'California-Kirkbride': 16.9,
#  'Carrick': 18.35,
#  'Central Business District': 0.1,
#  'Central Lawrenceville': 10.875,
#  'Central Northside': 23.799999999999997,
#  'Central Oakland': 14.375,
#  'Chartiers City': 19.425,
#  'Chateau': 18.175,
#  'Crafton Heights': 19.424999999999997,
#  'Crawford-Roberts': 21.475,
#  'Duquesne Heights': 10.275,
#  'East Allegheny': 16.475,
#  'East Carnegie': 15.649999999999999,
#  'East Hills': 24.4,
#  'East Liberty': 23.799999999999997,
#  'Elliott': 10.724999999999998,
#  'Esplen': 24.075000000000003,
#  'Fairywood': 20.875,
# ...

# %% [markdown]
# I then generate a score by averaging percent area of residential, industrial, commercial, and institutional area.
# This is based on the assumption that the optimal neighborhood would have a balenced array of zoning.

# %%
plt.bar(range(len(zoning_score)), list(zoning_score.values()), align='edge', width = 1)
plt.xticks(range(len(zoning_score)), list(zoning_score.keys()),rotation = 90)
plt.show()

# %% [markdown]
# As you can see we may have a few too many data points. So lets get rid of the useless data

# %%
score_av = 0.0
for x in zoning_score:
    score_av+=zoning_score[x]
score_av = score_av/len(zoning_score)
remove = []
for x in zoning_score:
    if zoning_score[x]<score_av:
        remove.append(x)
for x in remove:
    zoning_score.pop(x)
zoning_score
# Out:
# {'Allegheny West': 21.825,
#  'Banksville': 21.175,
#  'Beltzhoover': 17.175,
#  'Bloomfield': 23.6,
#  'Bluff': 18.975,
#  'Brookline': 19.549999999999997,
#  'Carrick': 18.35,
#  'Central Northside': 23.799999999999997,
#  'Chartiers City': 19.425,
#  'Chateau': 18.175,
#  'Crafton Heights': 19.424999999999997,
#  'Crawford-Roberts': 21.475,
#  'East Hills': 24.4,
#  'East Liberty': 23.799999999999997,
#  'Esplen': 24.075000000000003,
#  'Fairywood': 20.875,
#  'Friendship': 24.799999999999997,
#  'Garfield': 23.75,
#  'Greenfield': 20.625000000000004,
#  'Homewood North': 23.3,
#  'Homewood South': 24.200000000000003,
#  'Homewood West': 23.4,
#  'Knoxville': 24.975,
#  'Larimer': 22.25,
#  'Lincoln Place': 20.45,
#  'Lower Lawrenceville': 22.3,
#  'Manchester': 23.924999999999997,
#  'Marshall-Shadeland': 19.925,
#  'Middle Hill': 25.0,
#  'Morningside': 19.700000000000003,
#  'Mt. Oliver': 21.75,
#  'North Oakland': 20.725,
#  'Oakwood': 19.975,
# ...

# %%
plt.bar(range(len(zoning_score)), list(zoning_score.values()), align='edge', width = 1)
plt.xticks(range(len(zoning_score)), list(zoning_score.keys()),rotation = 90)
plt.show()

# %% [markdown]
# Now we can see all the above average scores

# %% [markdown]
# ## Lucas Milavec's Conclusion
# We can see that Knoxville, Friendship, and East Hills are the top 3 highest scoring neighborhoods from my analysis. This seems to be consistent with what you would expect from such an analysis because they are relatively well off neighborhoods fairly far from the downtown area. This allows theses neighborhoods to have the balance their use of space and provides residents with a better living condition. However, I am not personally very familiar with all the neighborhoods of Pittsburgh so it is difficult for me to truly evaluate the quality of my analysis.

# %% [markdown]
# ### Education (Anna Speciale)
# In my personal notebook I am attempting to figure out how Education can help define the "best" neighborhood in Pittsburgh. This data set has a column of neighborhood names and other columns consist of pupulation and percentages of people with certain levels of education attainment. These attainments include: less than high school, high school graduate, assoc./prof. degree, bachelor's degree, and postgraduate degree.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
education = pd.read_csv("./data/education-income.csv")
education
# Out:
#            Neighborhood  Sector # Population (2010)  \
# 0      Allegheny Center         3               933
# 1        Allegheny West         3               462
# 2             Allentown         6             2,500
# 3             Arlington         7             1,869
# 4     Arlington Heights         7               244
# ..                  ...       ...               ...
# 85  Upper Lawrenceville        13             2,669
# 86             West End         4               254
# 87         West Oakland        14             2,604
# 88             Westwood         4             3,066
# 89              Windgap         4             1,369
#
#    Total Pop, 25 and older (2010)  \
# 0                             609
# 1                             239
# 2                           1,729
# 3                           1,232
# 4                             166
# ..                            ...
# 85                          1,875
# 86                             86
# ...

# %%
education2 = education.drop(['Sector #', 'Population (2010)', 'Total Pop, 25 and older (2010)','Edu. Attainment: Less than High School (2010)', '1999 Median Income (\'99 Dollars)', '2009 Median Income (\'09 Dollars)', '1999 Median Income (\'11 Dollars)', '2009 Med. Income (\'13 Dollars)','Est. Pop. for which Poverty Calc. (2010)', 'Est. Pop. Under Poverty (2010)', 'Est. Percent Under Poverty (2010)'], axis=1)
education2.head(10)
# Out:
#         Neighborhood Edu. Attainment: High School Graduate (2010)  \
# 0   Allegheny Center                                        44.5%
# 1     Allegheny West                                        28.9%
# 2          Allentown                                        63.3%
# 3          Arlington                                        65.3%
# 4  Arlington Heights                                        74.1%
# 5         Banksville                                        51.5%
# 6  Bedford Dwellings                                        49.9%
# 7          Beechview                                        58.1%
# 8        Beltzhoover                                        54.3%
# 9         Bloomfield                                        42.6%
#
#   Edu. Attainment: Assoc./Prof. Degree (2010)  \
# 0                                       17.2%
# 1                                        6.7%
# 2                                        6.6%
# 3                                       10.1%
# ...

# %%
education2['Edu. Attainment: Postgraduate Degree (2010)'] = education2['Edu. Attainment: Postgraduate Degree (2010)'].str.rstrip('%').astype('float') / 100.0
education2
# Out:
#            Neighborhood Edu. Attainment: High School Graduate (2010)  \
# 0      Allegheny Center                                        44.5%
# 1        Allegheny West                                        28.9%
# 2             Allentown                                        63.3%
# 3             Arlington                                        65.3%
# 4     Arlington Heights                                        74.1%
# ..                  ...                                          ...
# 85  Upper Lawrenceville                                        65.7%
# 86             West End                                        36.0%
# 87         West Oakland                                        46.7%
# 88             Westwood                                        51.4%
# 89              Windgap                                        67.1%
#
#    Edu. Attainment: Assoc./Prof. Degree (2010)  \
# 0                                        17.2%
# ...

# %%
education2['Edu. Attainment: Bachelor\'s Degree (2010)'] = education2['Edu. Attainment: Bachelor\'s Degree (2010)'].str.rstrip('%').astype('float') / 100.0
education2
# Out:
#            Neighborhood Edu. Attainment: High School Graduate (2010)  \
# 0      Allegheny Center                                        44.5%
# 1        Allegheny West                                        28.9%
# 2             Allentown                                        63.3%
# 3             Arlington                                        65.3%
# 4     Arlington Heights                                        74.1%
# ..                  ...                                          ...
# 85  Upper Lawrenceville                                        65.7%
# 86             West End                                        36.0%
# 87         West Oakland                                        46.7%
# 88             Westwood                                        51.4%
# 89              Windgap                                        67.1%
#
#    Edu. Attainment: Assoc./Prof. Degree (2010)  \
# 0                                        17.2%
# ...

# %%
education2['Edu. Attainment: High School Graduate (2010)'] = education2['Edu. Attainment: High School Graduate (2010)'].str.rstrip('%').astype('float') / 100.0
education2
# Out:
#            Neighborhood  Edu. Attainment: High School Graduate (2010)  \
# 0      Allegheny Center                                         0.445
# 1        Allegheny West                                         0.289
# 2             Allentown                                         0.633
# 3             Arlington                                         0.653
# 4     Arlington Heights                                         0.741
# ..                  ...                                           ...
# 85  Upper Lawrenceville                                         0.657
# 86             West End                                         0.360
# 87         West Oakland                                         0.467
# 88             Westwood                                         0.514
# 89              Windgap                                         0.671
#
#    Edu. Attainment: Assoc./Prof. Degree (2010)  \
# 0                                        17.2%
# ...

# %%
education2['Edu. Attainment: Assoc./Prof. Degree (2010)'] = education2['Edu. Attainment: Assoc./Prof. Degree (2010)'].str.rstrip('%').astype('float') / 100.0
education2
# Out:
#            Neighborhood  Edu. Attainment: High School Graduate (2010)  \
# 0      Allegheny Center                                         0.445
# 1        Allegheny West                                         0.289
# 2             Allentown                                         0.633
# 3             Arlington                                         0.653
# 4     Arlington Heights                                         0.741
# ..                  ...                                           ...
# 85  Upper Lawrenceville                                         0.657
# 86             West End                                         0.360
# 87         West Oakland                                         0.467
# 88             Westwood                                         0.514
# 89              Windgap                                         0.671
#
#     Edu. Attainment: Assoc./Prof. Degree (2010)  \
# 0                                         0.172
# ...

# %%
education2.plot(x='Neighborhood', kind='bar', rot=90, figsize = (30,20))

# %%
condenseEducation1 = education2.loc[(education2['Edu. Attainment: High School Graduate (2010)'] > 0.05) & (education2['Edu. Attainment: Assoc./Prof. Degree (2010)'] > 0.05) & (education2['Edu. Attainment: Bachelor\'s Degree (2010)'] > 0.05) & (education2['Edu. Attainment: Postgraduate Degree (2010)'] >0.05)]
condenseEducation1.plot(x='Neighborhood', kind='bar', rot=90, figsize = (20,10))

# %% [markdown]
# **deciding to just focus on postgraduate degree.**

# %%
education3 = education2.drop(['Edu. Attainment: High School Graduate (2010)', 'Edu. Attainment: Assoc./Prof. Degree (2010)', 'Edu. Attainment: Bachelor\'s Degree (2010)'], axis=1)
education3['Edu. Attainment: Postgraduate Degree (2010)'] = education2['Edu. Attainment: Postgraduate Degree (2010)'].str.rstrip('%').astype('float') / 100.0
education3.head(10)
# Out:
#         Neighborhood  Edu. Attainment: Postgraduate Degree (2010)
# 0   Allegheny Center                                        0.038
# 1     Allegheny West                                        0.105
# 2          Allentown                                        0.015
# 3          Arlington                                        0.025
# 4  Arlington Heights                                        0.000
# 5         Banksville                                        0.066
# 6  Bedford Dwellings                                        0.147
# 7          Beechview                                        0.062
# 8        Beltzhoover                                        0.042
# 9         Bloomfield                                        0.135

# %%
condenseEducation = education3.loc[education3['Edu. Attainment: Postgraduate Degree (2010)'] > 0.15]
condenseEducation.plot(x='Neighborhood', kind='bar', rot=90, figsize = (20,10))

# %%
len(condenseEducation['Neighborhood'].unique())
# Out:
# 16

# %%
condenseEducation.sort_values("Edu. Attainment: Postgraduate Degree (2010)", ascending=False).head
# Out:
# <bound method NDFrame.head of                  Neighborhood  Edu. Attainment: Postgraduate Degree (2010)
# 70                South Shore                                        0.476
# 65              Regent Square                                        0.440
# 75        Squirrel Hill North                                        0.401
# 62               Point Breeze                                        0.325
# 76        Squirrel Hill South                                        0.320
# 39              Highland Park                                        0.318
# 55              North Oakland                                        0.299
# 67                  Shadyside                                        0.298
# 33                 Friendship                                        0.293
# 56                North Shore                                        0.286
# 63         Point Breeze North                                        0.214
# ...

# %% [markdown]
# **shows south shore as having the highest percentage attaining postgraduate degrees**

# %% [markdown]
# ## Anna Speciale's Conclusion
# For the sake of simplicity in the end I decide to focus on the percentage of the populations that attained postgraduate degrees. By this logic the highest percentage of people with a postgraduate degree, the highest form of education in this data set, would be considered the "best" neighborhood. The data set shows that South Shore has the highest percentage at 47.6% or .476. I am not from Pittsburgh so I don't think I have a personal favorite neighborhood. I can't really speak on whether or not these data sets align properly with how good the neighborhoods are since I haven't spent time in most of them.

# %% [markdown]
# # Group Conclusion
# Overall, the best neighborhood, the relative intersection between the three data sets, is Regent Square. Regent Square has an education attainment rate of 44%, which is the second-highest in Anna's dataset. It also has a 1.18% crime rate according to the metric used in Dastan Abdulla's data set. While Regent Square doesn't have the lowest crime rate, many neighborhoods have a small margin of less than 2% crime rate in the public safety dataset, which renders the margin irrelevant in the overall scope.
